# %% [markdown]
# # Process MOSI Video Features
# ---

# %%
import video_features_extraction as vf
import os

# %%
path = "../MOSI_Dataset/Segmented/_dI--eQ6qVU_"
features = vf.get_video_features(path)
# Out:
# Starting get the utterances...
# Utterance 5
# Utterance 10
# Utterance 15
# Utterance 20
# Utterance 25
# 28 utterances processed
# Starting modeling...

# %%
"../MOSI_Dataset/"

# %%
"/Users/silvana/Library/Mobile Documents/ Documents/com\~apple\~CloudDocs/EURECOM/SemProj/Raw\ -\ MOSI\ Dataset/Video/Segmented
# Out:
#   File "<ipython-input-1-8ddaa1a76d28>", line 1
#     "/Users/silvana/Library/Mobile\ Documents/com\~apple\~CloudDocs/EURECOM/SemProj/Raw\ -\ MOSI\ Dataset/Video/Segmented
#                                                                                                                           ^
# SyntaxError: EOL while scanning string literal

# %%
st = "/Users/silvana/Library/Mobile Documents/com~apple~CloudDocs/EURECOM/SemProj/Raw - MOSI Dataset/Video/Segmented"

# %%
st
# Out:
# '/Users/silvana/Library/Mobile Documents/com~apple~CloudDocs/EURECOM/SemProj/Raw - MOSI Dataset/Video/Full'

# %%
files = os.listdir(st)

# %%
f = files[0]
f
# Out:
# 'BI97DNYfe5I_10.mp4'

# %%
files
# Out:
# ['BI97DNYfe5I_10.mp4',
#  '1DmNV9C1hbY_4.mp4',
#  '03bSnISJMiM_7.mp4',
#  '8OtFthrtaJM_2.mp4',
#  '9c67fiY0wGQ_11.mp4',
#  '2WGyTLYerpo_33.mp4',
#  'IumbAb8q2dM_21.mp4',
#  'BvYR0L6f2Ig_4.mp4',
#  '.VCslbP0mgZI_8.mp4.icloud',
#  'atnd_PF-Lbs_16.mp4',
#  '2WGyTLYerpo_27.mp4',
#  'LSi-o-IrDMs_16.mp4',
#  'tmZoasNr4rU_2.mp4',
#  'zhpQhgha_KU_11.mp4',
#  'ZUXBRvtny7o_26.mp4',
#  '7JsX8y1ysxY_32.mp4',
#  'ZUXBRvtny7o_32.mp4',
#  '9J25DZhivz8_3.mp4',
#  'tIrG4oNLFzE_2.mp4',
#  '7JsX8y1ysxY_26.mp4',
#  'Bfr499ggo-0_7.mp4',
#  'rnaNMUZpvvg_6.mp4',
#  'tStelxIAHjw_2.mp4',
#  'Clx4VXItLTE_14.mp4',
#  '1iG0909rllw_16.mp4',
#  'Clx4VXItLTE_28.mp4',
#  'yvsjCA6Y5Fc_23.mp4',
#  'Iu2PFX3z_1s_1.mp4',
#  'BvYR0L6f2Ig_10.mp4',
#  'PZ-lDQFboO8_2.mp4',
#  'Qr1Ca94K55A_8.mp4',
#  'v0zCBqDeKcE_13.mp4',
#  'Ci-AH39fi3Y_39.mp4',
#  'TvyZBvOMOTc_14.mp4',
#  'Ci-AH39fi3Y_11.mp4',
#  'Njd1F0vZSm4_11.mp4',
#  'jUzDDGyPkXU_12.mp4',
#  'WKA5OygbEKI_17.mp4',
#  'iiK8YX8oH1E_13.mp4',
#  'W8NXH0Djyww_2.mp4',
# ...

# %%
files = [f for f in files if f[-4:] == '.mp4']
video_ids = [f[:f.rfind('_')] for f in files]
